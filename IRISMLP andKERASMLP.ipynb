# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

from sklearn.neural_network import MLPClassifier

X, y = load_iris(return_X_y=True)

# %%
#  80% training and 20% testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
stratify=y, random_state=42)

mlpClassifier = MLPClassifier(solver='lbfgs', alpha=1e-5,
hidden_layer_sizes=(10, 5), random_state=1)

# %%
mlpClassifier.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(10, 5), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=1, shuffle=True, solver='lbfgs',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
score = mlpClassifier.score(X_test, y_test)

print(score)
# Out:
# 0.9666666666666667

# %% [markdown]
# # Keras MLP for multi-class problem - Iris Dataset
# # Use the Iris dataset for multi-class classification. Train an MLP model using Keras.

# %%
from sklearn.datasets import load_iris

# %%
import tensorflow as tf
from tensorflow import keras

# %%
tf.set_random_seed(42)
np.random.seed(42)

# %%
irisdata=load_iris()
X=irisdata.data
y=irisdata.target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
sc.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
model_MLP = keras.models.Sequential()

model_MLP.add(keras.layers.Dense(units=15, activation='relu',input_shape= X_train.shape[1:]))

model_MLP.add(keras.layers.Dense(units=3, activation='softmax'))

# %%
model_MLP.compile(loss='sparse_categorical_crossentropy',
optimizer='adam', metrics=['accuracy'])

# %%
model_MLP.fit(x=X_train_std, y=y_train, validation_split=0.1,
epochs=50, batch_size=16)
# Out:
# Train on 108 samples, validate on 12 samples
# Epoch 1/50
# 108/108 [==============================] - 0s 3ms/sample - loss: 1.0942 - acc: 0.4259 - val_loss: 1.1993 - val_acc: 0.1667
# Epoch 2/50
# 108/108 [==============================] - 0s 127us/sample - loss: 1.0556 - acc: 0.4722 - val_loss: 1.1585 - val_acc: 0.1667
# Epoch 3/50
# 108/108 [==============================] - 0s 114us/sample - loss: 1.0180 - acc: 0.5278 - val_loss: 1.1206 - val_acc: 0.1667
# Epoch 4/50
# 108/108 [==============================] - 0s 121us/sample - loss: 0.9827 - acc: 0.5370 - val_loss: 1.0849 - val_acc: 0.1667
# Epoch 5/50
# 108/108 [==============================] - 0s 132us/sample - loss: 0.9482 - acc: 0.5463 - val_loss: 1.0499 - val_acc: 0.1667
# Epoch 6/50
# 108/108 [==============================] - 0s 133us/sample - loss: 0.9171 - acc: 0.5556 - val_loss: 1.0141 - val_acc: 0.1667
# Epoch 7/50
# 108/108 [==============================] - 0s 137us/sample - loss: 0.8849 - acc: 0.5556 - val_loss: 0.9815 - val_acc: 0.1667
# Epoch 8/50
# 108/108 [==============================] - 0s 113us/sample - loss: 0.8533 - acc: 0.5741 - val_loss: 0.9506 - val_acc: 0.2500
# Epoch 9/50
# 108/108 [==============================] - 0s 124us/sample - loss: 0.8254 - acc: 0.6481 - val_loss: 0.9180 - val_acc: 0.5833
# Epoch 10/50
# 108/108 [==============================] - 0s 131us/sample - loss: 0.7969 - acc: 0.8148 - val_loss: 0.8862 - val_acc: 0.6667
# Epoch 11/50
# 108/108 [==============================] - 0s 123us/sample - loss: 0.7670 - acc: 0.8426 - val_loss: 0.8570 - val_acc: 0.6667
# Epoch 12/50
# 108/108 [==============================] - 0s 146us/sample - loss: 0.7387 - acc: 0.8519 - val_loss: 0.8244 - val_acc: 0.6667
# Epoch 13/50
# 108/108 [==============================] - 0s 198us/sample - loss: 0.7097 - acc: 0.8519 - val_loss: 0.7942 - val_acc: 0.6667
# 108/108 [==============================] - 0s 128us/sample - loss: 0.3585 - acc: 0.8796 - val_loss: 0.4203 - val_acc: 0.7500
# Epoch 34/50
# 108/108 [==============================] - 0s 133us/sample - loss: 0.3505 - acc: 0.8796 - val_loss: 0.4142 - val_acc: 0.7500
# Epoch 35/50
# 108/108 [==============================] - 0s 144us/sample - loss: 0.3429 - acc: 0.8796 - val_loss: 0.4065 - val_acc: 0.7500
# Epoch 36/50
# 108/108 [==============================] - 0s 128us/sample - loss: 0.3360 - acc: 0.8796 - val_loss: 0.3993 - val_acc: 0.7500
# Epoch 37/50
# 108/108 [==============================] - 0s 133us/sample - loss: 0.3295 - acc: 0.8796 - val_loss: 0.3918 - val_acc: 0.7500
# Epoch 38/50
# 108/108 [==============================] - 0s 116us/sample - loss: 0.3231 - acc: 0.8889 - val_loss: 0.3851 - val_acc: 0.7500
# Epoch 39/50
# 108/108 [==============================] - 0s 122us/sample - loss: 0.3170 - acc: 0.8889 - val_loss: 0.3786 - val_acc: 0.7500
# Epoch 40/50
# 108/108 [==============================] - 0s 157us/sample - loss: 0.3113 - acc: 0.8889 - val_loss: 0.3728 - val_acc: 0.7500
# Epoch 41/50
# 108/108 [==============================] - 0s 139us/sample - loss: 0.3062 - acc: 0.8889 - val_loss: 0.3661 - val_acc: 0.7500
# Epoch 42/50
# 108/108 [==============================] - 0s 133us/sample - loss: 0.3010 - acc: 0.8889 - val_loss: 0.3616 - val_acc: 0.7500
# Epoch 43/50
# 108/108 [==============================] - 0s 177us/sample - loss: 0.2962 - acc: 0.8889 - val_loss: 0.3567 - val_acc: 0.7500
# Epoch 44/50
# 108/108 [==============================] - 0s 150us/sample - loss: 0.2916 - acc: 0.8889 - val_loss: 0.3517 - val_acc: 0.7500
# Epoch 45/50
# 108/108 [==============================] - 0s 128us/sample - loss: 0.2872 - acc: 0.8889 - val_loss: 0.3469 - val_acc: 0.7500
# Epoch 46/50
# 108/108 [==============================] - 0s 141us/sample - loss: 0.2832 - acc: 0.8889 - val_loss: 0.3416 - val_acc: 0.7500
# Epoch 47/50
# 108/108 [==============================] - 0s 119us/sample - loss: 0.2792 - acc: 0.8889 - val_loss: 0.3371 - val_acc: 0.7500
# Epoch 48/50
# 108/108 [==============================] - 0s 119us/sample - loss: 0.2755 - acc: 0.8889 - val_loss: 0.3321 - val_acc: 0.7500
# Epoch 49/50
# 108/108 [==============================] - 0s 119us/sample - loss: 0.2716 - acc: 0.8889 - val_loss: 0.3284 - val_acc: 0.7500
# Epoch 50/50
# 108/108 [==============================] - 0s 119us/sample - loss: 0.2682 - acc: 0.8889 - val_loss: 0.3247 - val_acc: 0.7500

# %%
test_loss, test_accuracy = model_MLP.evaluate(x=X_test_std, y=y_test)
# Out:
# 30/30 [==============================] - 0s 109us/sample - loss: 0.3318 - acc: 0.8000

# %%
print(test_loss, test_accuracy)
# Out:
# 0.33175763487815857 0.8
